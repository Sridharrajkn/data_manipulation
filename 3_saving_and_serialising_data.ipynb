# %% [markdown]
# Saving and serialising

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.random(size = (100, 4)), columns=["A","B","C","D"])
df
# Out:
#            A         B         C         D
# 0   0.662009  0.202488  0.983570  0.307853
# 1   0.195215  0.930689  0.982220  0.024700
# 2   0.367302  0.232280  0.768863  0.562370
# 3   0.340710  0.756808  0.368335  0.760720
# 4   0.043490  0.867884  0.462076  0.000109
# ..       ...       ...       ...       ...
# 95  0.237587  0.729041  0.061703  0.958298
# 96  0.440655  0.744876  0.386667  0.574841
# 97  0.207843  0.937583  0.004983  0.445900
# 98  0.128733  0.199480  0.890937  0.741626
# 99  0.012777  0.125355  0.933660  0.496402
#
# [100 rows x 4 columns]

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.662009  0.202488  0.983570  0.307853
# 1  0.195215  0.930689  0.982220  0.024700
# 2  0.367302  0.232280  0.768863  0.562370
# 3  0.340710  0.756808  0.368335  0.760720
# 4  0.043490  0.867884  0.462076  0.000109

# %%
df.to_csv("save.csv", index= False, float_format="%-0.4f")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-12-6b8e15ff41da> in <module>
# ----> 1 df.to_csv("save.csv", index= False, float_format="%-0.4f")
#
# F:\anaconda\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ...

# %%
df.to_hdf("save.hdf", key="data", format="table")

# %%
filename = pd.read_csv("P87-S2-Dataset-Basics-Resources/astronauts.csv")
filename.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
filename.to_csv("save.csv", index=False, float_format="%0.4f")

# %%
pd.read_csv("save.csv").head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is AABC-B224
#
#  Directory of C:\Users\hp\Desktop\udemy_datamanipulation
#
# 10/02/2021  12:20 AM    <DIR>          .
# 10/02/2021  12:20 AM    <DIR>          ..
# 10/01/2021  11:57 PM    <DIR>          .ipynb_checkpoints
# 10/01/2021  11:55 PM             7,022 creating_dataframes.ipynb
# 10/01/2021  05:20 PM    <DIR>          heart_disease_uci
# 10/01/2021  07:45 PM            73,041 how_to_load_dataset.ipynb
# 10/01/2021  04:30 PM            26,337 loading.ipynb
# 03/27/2020  07:08 PM    <DIR>          P87-S2-Dataset-Basics-Resources
# 10/01/2021  04:08 PM            54,129 P87-Section-2-Dataset-Basics-Resources.zip
# 10/02/2021  12:19 AM            87,030 save.csv
# 10/02/2021  12:10 AM            84,197 save.hdf
# 10/02/2021  12:20 AM            23,405 saving_and_serialising_data.ipynb
# 10/01/2021  03:52 PM                72 Untitled.ipynb
# 10/01/2021  05:17 PM                72 Untitled1.ipynb
# ...
